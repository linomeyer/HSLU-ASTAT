# %% [markdown]
# # <span style="color:rgb(160,0,86)">Schätzverfahren</span>
#
# ***

# %% [markdown]
# ## <span style="color:rgb(160,0,86)">Lernziele</span>
#
# - Sie kennen Schätzverfahren für Parameter der Grundgesamtheit.
# - Sie können Punktschätzer von Interallschätzern unterscheiden.
# - Sie können für die wichte Parameter diese Schätzer berechnen.
#
# ***

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Was sind Schätzverfahren?</span>
#
# Die **Schätztheorie** ist ein Teilgebiet der Statistik. Mit mathematischen Verfahren sollen *unbekannte Verteilungsparameter* (mittlere Lage, Streuung, etc.) einer Grundgesamtheit auf Basis von Zufallsstichproben *geschätzt werden*. Es wird zwischen **Punktschätzugen** und **Intervallschätzungen** unterschieden.
#
# <span style="color:rgb(160,0,86)">***Punktschätzer:***</span> Ein Punktschätzer gibt **einen einzelnen Wert** als Schätzung für einen unbekannten Parameter an.
#
# - *Beispiel:* Der **Mittelwert** $\pmb{\bar{x}}$ einer Stichprobe als Schätzung für den wahren **Mittelwert** $\pmb{\mu}$ der Grundgesamtheit. Die **relative Häufigkeit** $\pmb{h(\;)}$ in einer Stichprobe als Schätzung für die tatsächliche **Wahrscheinlichkeit** $\pmb{P(\;)}$ in der Grundgesamtheit.
# - *Vorteil:* Einfach und direkt interpretierbar.
# - *Nachteil:* Enthält keine Information über die Unsicherheit der Schätzung.
#
# Ein Punktschätzer ist wie eine einzelne Zahl auf einer Zielscheibe – er kann genau treffen oder danebenliegen.
#
#
# <span style="color:rgb(160,0,86)">***Intervallschätzer:***</span> Ein Intervallschätzer gibt **ein Intervall** an, in dem der wahre Parameter mit einer bestimmten Wahrscheinlichkeit liegt.
#
# - *Beispiel:* Ein **95%-Konfidenzintervall** $\pmb{[\bar{x}_{\text{min}},\bar{x}_{\text{max}}]}$ für den Mittelwert gibt an, in welchem Bereich der wahre Mittelwert der Grundgesamtheit mit einer Wahrscheinlichkeit von 95% liegt.
# - *Vorteil:* Enthält Informationen über die Unsicherheit der Schätzung.
# - *Nachteil:* Komplexer als ein einzelner Punktwert.
#
# Ein Intervallschätzer ist wie ein Zielfernrohr, das eine gewisse Streuung zulässt – es gibt nicht nur eine Zahl, sondern einen Bereich möglicher Werte an.

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Wie werden Punktschätzer festgelet?</span>
#
# Häufig werden Punktschätzer mit einer der folgenden Methoden bestimmt.
#
# <span style="color:rgb(160,0,86)">***Kleinste-Quadrate-Schätzung LSE:***</span>
#
# Man macht keine Annahmen über die Verteilung in der Grundgesamtheit und zieht eine Zufallsstichprobe $x_1,x_2,\ldots,x_n$.
#
# - *Ziel:* Die Summe der quadrierten Fehler $\mathsf{SSE}$ zwischen den beobachteten Werten und dem vorhergesagten Wert werden minimiert. Der **Schätzer** $\pmb{\hat{\mu}}$ für den Mittelwert $\mu$ einer Grundgesamtheit hat also die Eigenschaft, dass für die gegebene Stichprobe die Zahl $$\mathsf{SSE}(\pmb{\hat{\mu}})=(x_1-\pmb{\hat{\mu}})^2 + (x_2-\pmb{\hat{\mu}})^2 + (x_3-\pmb{\hat{\mu}})^2 + \cdots + (x_n-\pmb{\hat{\mu}})^2$$ minimal ist. Mit den Methoden der Analysis folgt, dass $$\pmb{\hat{\mu}} = \frac{1}{n}(x_1 + x_2 + x_3 + \cdots + x_n)$$ gerechnet werden muss. Der Mittelwert $\mu$ wird also mit dem **arithmetischen Mittel** geschätzt.
#
#
# <span style="color:rgb(160,0,86)">***Maximum-Likelihood-Schätzung MLE:***</span>
#
# Man nimmt an, dass die Daten der Grundgesamtheit aus einer bestimmten Verteilung stammen (z.B. Normalverteilung, Binomialverteilung, Poissonverteilung etc.) und zieht eine Zufallsstichprobe $x_1,x_2,\ldots,x_n$. Der Parameter $\mu$ dieser Verteilung ist aber unbekannt.
#
# - *Ziel:* Wenn man zum Beispiel davon aus geht, dass die Daten Normalverteilt sind, dann gibt die sogenannte Likelihood-Funktion $$L(\pmb{\hat{\mu}})=
# \underbrace{\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x_1-\pmb{\hat{\mu}})^2}{2\sigma^2}}}_{P(X_1=x_1)\rule{0cm}{0.55cm}}\cdot
# \underbrace{\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x_2-\pmb{\hat{\mu}})^2}{2\sigma^2}}}_{P(X_2=x_2)\rule{0cm}{0.55cm}}\cdot
# \underbrace{\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x_3-\pmb{\hat{\mu}})^2}{2\sigma^2}}}_{P(X_3=x_3)\rule{0cm}{0.55cm}}\cdot\ldots
# \underbrace{\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x_n-\pmb{\hat{\mu}})^2}{2\sigma^2}}}_{P(X_n=x_n)\rule{0cm}{0.55cm}}\cdot$$ an, wie wahrscheinlich die Daten $x_1,x_2,\ldots,x_n$ der Stichprobe mit einem **Schätzer** $\pmb{\hat{\mu}}$ für den Mittelwert $\mu$ der gewählten Verteilung sind. Den Schätzer $\pmb{\hat{\mu}}$ für den Parameter $\mu$ bestimmt man so, dass die Likelihood-Funktion $L$ am grössten ist. Das bedeutet also, dass der Parameter $\pmb{\hat{\mu}}$ die beobachteten Daten am wahrscheinlichsten erklärt.  Mit den Methoden der Analysis folgt, dass $$\pmb{\hat{\mu}} = \frac{1}{n}(x_1 + x_2 + x_3 + \cdots + x_n)$$ gerechnet werden muss. Der Mittelwert $\mu$ muss also auch mit dem **arithmetischen Mittel** geschätzt werden.

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Welche Eigenschaften sollten Punktschätzer haben?</span>
#
# - Eine Schätzer heisst **konsistent**, wenn mit zunehmendem Stichprobenumfang $n$ grosse Abweichungen zwischen dem wahren Parameter und dem geschätzten Parameter immer seltener werden.
#
# - Ein Schätzer heisst **erwartungstreu**, wenn er im Mittel über alle Stichproben den wahren Parameter richtig schätzt.
#
# Der *Stichprobenmedian* ist der Median der geordneten Stichprobe. Er ist im Allgemeinen **nicht erwartungstreu** für den wahren Median der Grundgesamtheit, dennoch ist er **konsistent**, das heisst, für grosse Stichproben nähert er sich dem wahren Median an.

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Aufgabe 1</span>
#
# Wir betrachten eine kleine Grundgesamtheit von 5 Personen:
#
# $$\begin{array}{c|cccc}
# &\text{PKW-Besitz }Y&\text{Einkünfte }X\\ \hline
# \text{Person A}&1&800\\
# \text{Person B}&0&600\\
# \text{Person C}&1&900\\
# \text{Person D}&1&800\\
# \text{Person E}&0&700\\
# \end{array}$$
#
# Aus dieser Grundgesamtheit wird eine Stichprobe $$\begin{array}{c|cccc}
# &\text{PKW-Besitz }Y&\text{Einkünfte }X\\ \hline
# \text{Person 1}&y_1&x_1\\
# \text{Person 2}&y_2&x_2\\
# \end{array}$$ vom Umfang $n=2$, um den **Anteil PKW-Besitzer** $\pmb{p}$, die **durchschnittlichen Einkünfte** $\pmb{\mu}$ und die **Varianz der Einkünfte** $\pmb{\sigma^2}$ zu schätzen.
#
# Es werden folgende Schätzer verwendet:
# - $\displaystyle\pmb{\hat{p}}=\frac{1}{2}(y_1+y_2)$
# - $\displaystyle\pmb{\hat{\mu}}=\frac{1}{2}(x_1+x_2)\rule{0cm}{1.5cm}$
# - $\displaystyle\pmb{\hat{\sigma}^2}=\frac{1}{2}\big((x_1-\pmb{\hat{\mu}})^2+(x_2-\pmb{\hat{\mu}})^2)\big)\rule{0cm}{1.5cm}$
#
# 1) Bestimmen Sie die wahren Parameter $\pmb{p}$, $\pmb{\mu}$ und $\pmb{\sigma^2}$ in der Grundgesamtheit.
# 2) Bestimmen Sie die Schätzungen der Parameter für alle möglichen Stichproben mit zurücklegen.
# 3) Bestimmen Sie die Schätzungen der Parameter für alle möglichen Stichproben ohne zurücklegen.
# 4) Sind die Schätzer bei 2) und 3) **erwartungstreu**?

# %% [markdown]
# ***
#
# ### <span style="color:rgb(160,0,86)">Lösungsvorschlag</span>
#
# Diese Aufgabe kann auch von Hand gelöst werden. Eine Lösung mit Python finden wir zum Beispiel wie folgt:
#
# Speichern wir die **Daten der Grundgesamtheit** in einem *DataFrame* von pandas:

# %%
personen = ["A", "B", "C", "D", "E"]
pkw_Besitz = [1, 0, 1, 1, 0]
einkünfte = [800, 600, 900, 800, 700]

import pandas as pd

grundgesamtheit = pd.DataFrame({"Personen": personen,
                                "PKW": pkw_Besitz,
                                "Einkünfte": einkünfte})

grundgesamtheit.set_index("Personen", inplace=True)
grundgesamtheit
# Out:
#           PKW  Einkünfte
# Personen
# A           1        800
# B           0        600
# C           1        900
# D           1        800
# E           0        700

# %% [markdown]
# Die wahren Paramter $\pmb{p}$, $\pmb{\mu}$ und $\pmb{\sigma^2}$ in der Grundgesamtheit sind:

# %%
import numpy as np

p_pkw = grundgesamtheit["PKW"].mean()
erwartungswert_einkünfte = grundgesamtheit["Einkünfte"].mean()
var_einkünfte = grundgesamtheit["Einkünfte"].var(ddof=0)

print("p_pkw =", np.round(p_pkw, 1))
print("mu_einkünfte =", np.round(erwartungswert_einkünfte, 1), "und",
      "var_einkünfte =", np.round(var_einkünfte, 1))
# Out:
# p_pkw = 0.6
# mu_einkünfte = 760.0 und var_einkünfte = 10400.0

# %% [markdown]
# Schätzungen $\pmb{\hat{p}}$, $\pmb{\hat{\mu}}$ und $\pmb{\hat{\sigma}^2}$ für alle Stichproben der Grösse $n=2$ **mit Zurücklegen** und **ohne Zurücklegen**:

# %%
#wir sammeln alle Stichproben und die Schätzer in Listen
#Initialisierung
stichprobe_mZ = []
schätzungPKW_p = []
schätzungEinkünfte_mu = []
schätzungEinkünfte_var = []

#Berechnung
for i in grundgesamtheit.index:  #i: 1. Person in der Stichprobe
    for j in grundgesamtheit.index:  #j: 2. Person in der Stichprobe
        stichprobe_mZ.append(i + j)  #"ij" als Name für die Stichprobe
        #Schätzungen aus der Stichprobe berechnen und speichern  
        schätzungPKW_p.append(1 / 2 * (grundgesamtheit.loc[i, "PKW"] +
                                       grundgesamtheit.loc[j, "PKW"]))
        mu_hat = 1 / 2 * (grundgesamtheit.loc[i, "Einkünfte"] +
                          grundgesamtheit.loc[j, "Einkünfte"])
        schätzungEinkünfte_mu.append(mu_hat)
        schätzungEinkünfte_var.append(
            1 / 2 * ((grundgesamtheit.loc[i, "Einkünfte"] - mu_hat) ** 2 +
                     (grundgesamtheit.loc[j, "Einkünfte"] - mu_hat) ** 2))

#Wir speichern alle Stichproben mit den Schätzern in einem pandas DataFrame
schätzungen_mZ = pd.DataFrame(
    {"Stichprobe": stichprobe_mZ,
     "p_hat": schätzungPKW_p,
     "mu_hat": schätzungEinkünfte_mu,
     "var_hat": schätzungEinkünfte_var})
schätzungen_mZ.set_index("Stichprobe", inplace=True)
#Für die Stichproben ohne Zurücklegen nehmen wir die unerlaubten weg
schätzungen_oZ = schätzungen_mZ.drop(["AA", "BB", "CC", "DD", "EE"])
schätzungen_mZ.head(), schätzungen_oZ.head()
# Out:
# (            p_hat  mu_hat  var_hat
#  Stichprobe
#  AA            1.0   800.0      0.0
#  AB            0.5   700.0  10000.0
#  AC            1.0   850.0   2500.0
#  AD            1.0   800.0      0.0
#  AE            0.5   750.0   2500.0,
#              p_hat  mu_hat  var_hat
#  Stichprobe
#  AB            0.5   700.0  10000.0
#  AC            1.0   850.0   2500.0
#  AD            1.0   800.0      0.0
#  AE            0.5   750.0   2500.0
#  BA            0.5   700.0  10000.0)

# %% [markdown]
# Nun prüfen wir, ob die Schätzungen $\pmb{\hat{p}}$, $\pmb{\hat{\mu}}$ und $\pmb{\hat{\sigma}^2}$ erwartungstreu sind.
#
# Mit diesen Stichproben der Grösse $n=2$ finden wir für $\pmb{\hat{p}}$:

# %%
print("Mittel über alle Stichproben ohne Zurücklegen ist",
      schätzungen_oZ["p_hat"].mean())
print("Mittel über alle Stichproben mit Zurücklegen ist",
      schätzungen_mZ["p_hat"].mean())
print("Wahre Wert in der Grundgesamtheit ist", p_pkw)
# Out:
# Mittel über alle Stichproben ohne Zurücklegen ist 0.6
# Mittel über alle Stichproben mit Zurücklegen ist 0.6
# Wahre Wert in der Grundgesamtheit ist 0.6

# %% [markdown]
# - Der Schätzer $\displaystyle\pmb{\hat{p}}=\frac{1}{2}(y_1+y_2)$ für den Anteil $\displaystyle\pmb{p}$ ist sowohl für Stichproben **mit Zurücklegen** als auch für Stichproben **ohne Zurücklegen** ***erwartungstreue***.

# %% [markdown]
# Für $\pmb{\hat{\mu}}$ finden wir:

# %%
print("Mittel über alle Stichproben ohne Zurücklegen ist",
      schätzungen_oZ["mu_hat"].mean())
print("Mittel über alle Stichproben mit Zurücklegen ist",
      schätzungen_mZ["mu_hat"].mean())
print("Wahre Wert in der Grundgesamtheit ist", erwartungswert_einkünfte)
# Out:
# Mittel über alle Stichproben ohne Zurücklegen ist 760.0
# Mittel über alle Stichproben mit Zurücklegen ist 760.0
# Wahre Wert in der Grundgesamtheit ist 760.0

# %% [markdown]
# - Der Schätzer $\displaystyle\pmb{\hat{\mu}}=\frac{1}{2}(x_1+x_2)\rule{0cm}{1.5cm}$ für den Mittelwert $\displaystyle\pmb{\mu}$ ist sowohl für Stichproben **mit Zurücklegen** als auch für Stichproben **ohne Zurücklegen** ***erwartungstreue***.

# %% [markdown]
# Für $\pmb{\hat{\sigma}^2}$ finden wir:

# %%
print("Mittel über alle Stichproben ohne Zurücklegen ist",
      schätzungen_oZ["var_hat"].mean())
print("Mittel über alle Stichproben mit Zurücklegen ist",
      schätzungen_mZ["var_hat"].mean())
print("Wahre Wert in der Grundgesamtheit ist", var_einkünfte)
# Out:
# Mittel über alle Stichproben ohne Zurücklegen ist 6500.0
# Mittel über alle Stichproben mit Zurücklegen ist 5200.0
# Wahre Wert in der Grundgesamtheit ist 10400.0

# %% [markdown]
# - Der Schätzer $\displaystyle\pmb{\hat{\sigma}^2}=\frac{1}{2}\big((x_1-\pmb{\hat{\mu}})^2+(x_2-\pmb{\hat{\mu}})^2)\big)\rule{0cm}{1.5cm}$ für die Varianz $\displaystyle\pmb{\sigma^2}$ ist sowohl für Stichproben **mit Zurücklegen** als auch für Stichproben **ohne Zurücklegen** **<span style="color:red">nicht</span>** ***erwartungstreue***.
#
# Die folgenden Berechnungen zeigen, dass:
#
# - der Schätzer $\displaystyle\pmb{\hat{\sigma}_1^2}=\frac{1}{\textcolor{red}{\pmb{2-1}}}\big((x_1-\pmb{\hat{\mu}})^2+(x_2-\pmb{\hat{\mu}})^2)\big)\rule{0cm}{0.8cm}$ für Stichproben **mit Zurücklegen** ***erwartungstreu*** ist.
# - der Schätzer $\displaystyle\pmb{\hat{\sigma}_2^2}=\frac{\textcolor{red}{\pmb{5-1}}}{\textcolor{red}{\pmb{5}}}\cdot\frac{1}{\textcolor{red}{\pmb{2-1}}}\big((x_1-\pmb{\hat{\mu}})^2+(x_2-\pmb{\hat{\mu}})^2)\big)\rule{0cm}{1.5cm}$ für Stichproben **ohne Zurücklegen** ***erwartungstreu*** ist.

# %%
stichprobe_mZ = []
schätzungEinkünfte_var1 = []
schätzungEinkünfte_var2 = []

for i in grundgesamtheit.index:  #i: 1. Person in der Stichprobe
    for j in grundgesamtheit.index:  #j: 2. Person in der Stichprobe
        stichprobe_mZ.append(i + j)  #"ij" als Name für die Stichprobe
        #Schätzungen aus der Stichprobe berechnen und speichern  
        mu_hat = 1 / 2 * (grundgesamtheit.loc[i, "Einkünfte"] +
                          grundgesamtheit.loc[j, "Einkünfte"])
        schätzungEinkünfte_var1.append(
            1 / (2 - 1) * ((grundgesamtheit.loc[i, "Einkünfte"] - mu_hat) ** 2 +
                           (grundgesamtheit.loc[j, "Einkünfte"] - mu_hat) ** 2))
        schätzungEinkünfte_var2.append(
            (5 - 1) / 5 * 1 / (2 - 1) * ((grundgesamtheit.loc[i, "Einkünfte"] - mu_hat) ** 2 +
                                         (grundgesamtheit.loc[j, "Einkünfte"] - mu_hat) ** 2))

schätzungen_var_mZ = pd.DataFrame(
    {"Stichprobe": stichprobe_mZ,
     "var_hat1": schätzungEinkünfte_var1,
     "var_hat2": schätzungEinkünfte_var2})
schätzungen_var_mZ.set_index("Stichprobe", inplace=True)

#Für die Stichproben ohne Zurücklegen nehmen wir die unerlaubten weg
schätzungen_var_oZ = schätzungen_var_mZ.drop(["AA", "BB", "CC", "DD", "EE"])

#Das Mittel über die Stichproben bestätigt die erwartungstreue der Schätzer:
print("Mittel über alle Stichproben mit Zurücklegen ist",
      schätzungen_var_mZ["var_hat1"].mean())
print("Mittel über alle Stichproben ohne Zurücklegen ist",
      schätzungen_var_oZ["var_hat2"].mean())
print("Wahre Wert in der Grundgesamtheit ist", var_einkünfte)
# Out:
# Mittel über alle Stichproben mit Zurücklegen ist 10400.0
# Mittel über alle Stichproben ohne Zurücklegen ist 10400.0
# Wahre Wert in der Grundgesamtheit ist 10400.0

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Welche Punktschätzer werden gebraucht?</span>
#
# Gegeben sei eine Zufallsstichprobe $x_1,x_2,x_3,\ldots,x_n$ vom Umfang $n$ aus einer Grundgesamtheit vom Umfang $N$. Die folgenden Schätzer sind *erwartungstreu*:
# - Für den **Mittelwert** $\pmb{\mu}$ brauchen wir $$\pmb{\hat{\mu}}=\frac{1}{n}(x_1+x_2+x_3+\cdots + x_n) $$
# - Für die **Varianz** $\pmb{\sigma^2}$ brauchen wir in Stichproben **mit Zurücklegen** $$\pmb{\hat{\sigma}^2}=\frac{1}{\textcolor{red}{\pmb{n-1}}}\big((x_1-\bar{x})^2+(x_2-\bar{x})^2+(x_3-\bar{x})^2+\cdots + (x_n-\bar{x})^2\big) $$ und in Stichproben **ohne Zurücklegen** $$\pmb{\hat{\sigma}^2}=\frac{\textcolor{red}{\pmb{N-1}}}{\textcolor{red}{\pmb{N}}}\cdot\frac{1}{\textcolor{red}{\pmb{n-1}}}\big((x_1-\bar{x})^2+(x_2-\bar{x})^2+(x_3-\bar{x})^2+\cdots + (x_n-\bar{x})^2\big) $$
#
# Beachten Sie, dass die **mittlere quadratische Abweichung** $MQD$ *kein* erwartungstreuer Schätzer für die Varianz ist, sie ist nur konsistent!

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Wie werden Intervallschätzer berechnet?</span>
#
# Während bei der Punktschätzung aus einer Zufallsstichprobe $x_1,x_2,x_3,\ldots,x_n$ nur ein punktueller Schätzwert ermittelt wird, informiert eine Intervallschätzung zusätzlich über den **Stichprobenfehler**. Sie stellt also einen Zusammenhang zwischen der Punktschätzung und dem Parameterwert der Grundgesamtheit her.
#
# Bei der Intervallschätzung wird für einen unbekannten Paramter $\pmb{\theta}$ zunächst aus einer Stichprobe eine Punktschätzung $\pmb{\hat{\theta}}$ berechnet, um die herum dann ein (meist symmetrisches) **Konfidenzintervall** konstruiert wird: $$K=[\pmb{\hat{\theta}-\delta_n},\pmb{\hat{\theta}+\delta_n}]$$
# Dabei wird der Stichprobenfehler $\pmb{\delta_n}$ so bestimmt, dass das Konfidenzintervall den unbekannten Parameter $\pmb{\theta}$ mit einer vorgegebenen Wahrscheinlichkeit überdeckt: $$P(\theta\in K) = \alpha$$ Diese Wahrscheinlichkeit $\alpha$  heisst **Konfidenzniveau**. Üblicherweise wereden in der Praxis Konfidenzniveaus von 95% oder 99% gewählt.
#
# <center>
# <img src="Bilder/Konfidenz.png" width="50%" />
# </center>
#
# In der klassischen Statistik wird der Stichprobenfehler $\pmb{\delta}$ für Mittelwerte mathematisch mit Formelen, insbesondere mit der $t$-Verteilung ermittelt: $$ \delta = \big\{(1-\alpha/2)\text{ Quantil von der Verteilung }t(n-1) \big\}\cdot \frac{\hat{\sigma}}{\sqrt{n}}\qquad $$
# Dabei wird angenommen, dass die Daten *normalverteilt* sind, was für Stichprobenmittelwerte zutrifft.
#
#
# Eine moderne Möglichkeit (mit einem Computer) Konfidenzintervalle zu berechnen bietet das **Bootstrap-Verfahren**. Ein $\pmb{\alpha\%}$**-Konfidenzintervall** eines Parametres sollte im Durchschnitt in $\pmb{\alpha\%}$ der Fälle die gleichen Stichprobenschätzer abdecken, sofern zur Stichprobenerhebung dasselbe Verfahren verwednet wird.
#
# Angenommen wir hätten eine Stichprobe der Grösse $n$ und interessierten uns für einen bestimmen Parameter. Dann können wir mit dem folgenden Algorithmus ein **Bootstrap-Konfidenzintervall** berechnen:
#
# 1) Ziehe eine Zufallsstichprobe (ein **Resample**) **mit Zurücklegen** der Grösse $n$ aus den Daten.
# 2) Erfasse den im Fokus stehende Parameter für das Resample.
# 3) Wiederhole die Schritte 1 und 2 viele Male.
# 4) Zur Ermittlung des $\pmb{\alpha\%}$**-Konfidenzintervall** müssen wir nun $$\big((100-\pmb{\alpha})/2\big)\%$$ der **geordneten** Werte der Resamples an beiden Enden abschneiden. Beim 95%-Konfidenzintervall müssen wir also links und rechts 2.5% der Daten abschneiden, beim 99%-Konfidenzintervall müssen wir 0.5% der Daten links und rechts abschneiden.
# 5) Die zwei Werte, an denen die **geordneten** Werte der Resamples gestutz wurden, bilden die entsprechenden Konfidenzschranken des $\pmb{\alpha\%}$**-Konfidenzintervall**.

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Aufgabe 2</span>
#
# Laden Sie die Datei *loans_income.csv* im Ordner Daten und nehmen je 1000  **Zufallsstichproben** vom Umfang $n=4,8,16,32,64,128$ aus diesen Daten.
#
# - Schätzen Sie den wahren Mittelwert und die wahre Standardabweichung der Löhne mit diesen Stichproben und vergleichen Sie diese Schätzungen mit den wahren Parametern.
# - Bestimmen Sie mit Resamples basierend auf einer Stichprobe mit $n=128$ ein 95\%- und ein 99\%-Konfidenzintervall für den Mittelwert der Löhne.

# %% [markdown]
# ***
#
# ### <span style="color:rgb(160,0,86)">Lösungsvorschlag</span>

# %%
import numpy as np
import pandas as pd

income = pd.read_csv("Daten/loans_income.csv")


def samples(anz, n):
    Samples = ["x" + str(i) for i in range(n)]
    sample = pd.DataFrame(columns=Samples)
    for i in range(anz):
        sample.loc[i] = np.random.choice(income["x"], size=n, replace=True)
    sample["mu_hat"] = sample[Samples].mean(axis=1)
    sample["std_hat"] = sample[Samples].std(axis=1, ddof=1)
    return sample


sample_4 = samples(1000, 4)
sample_8 = samples(1000, 8)
sample_16 = samples(1000, 16)
sample_32 = samples(1000, 32)
sample_64 = samples(1000, 64)
sample_128 = samples(1000, 128)

# %%
income_mu = income["x"].mean(axis=0)
income_std = income["x"].std(axis=0, ddof=0)

#je ein Dichtediagramm für 
# - die Stichprobenmittelwerte
# - die Stichprobenstandardabweichungen
import matplotlib.pyplot as plt
import seaborn as sns


def draw_mu(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(income_mu - 2 * income_std, income_mu + 2 * income_std)
    ax = plt.axvline(income_mu, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\mu=$" + "{m:1.1f}".format(m=income_mu),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenmittelwerte für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


def draw_std(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(income_std - 1.5 * income_std, income_std + 1.5 * income_std)
    ax = plt.axvline(income_std, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\sigma=$" + "{m:1.1f}".format(m=income_std),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenstandardabweichungen für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


fig = plt.figure(figsize=(15, 30))
ax = fig.add_subplot(6, 2, 1)
draw_mu(sample_4["mu_hat"], "4")
ax = fig.add_subplot(6, 2, 2)
draw_std(sample_4["std_hat"], "4")
ax = fig.add_subplot(6, 2, 3)
draw_mu(sample_8["mu_hat"], "8")
ax = fig.add_subplot(6, 2, 4)
draw_std(sample_8["std_hat"], "8")
ax = fig.add_subplot(6, 2, 5)
draw_mu(sample_16["mu_hat"], "16")
ax = fig.add_subplot(6, 2, 6)
draw_std(sample_16["std_hat"], "16")
ax = fig.add_subplot(6, 2, 7)
draw_mu(sample_32["mu_hat"], "32")
ax = fig.add_subplot(6, 2, 8)
draw_std(sample_32["std_hat"], "32")
ax = fig.add_subplot(6, 2, 9)
draw_mu(sample_64["mu_hat"], "64")
ax = fig.add_subplot(6, 2, 10)
draw_std(sample_64["std_hat"], "64")
ax = fig.add_subplot(6, 2, 11)
draw_mu(sample_128["mu_hat"], "128")
ax = fig.add_subplot(6, 2, 12)
draw_std(sample_128["std_hat"], "128")

plt.show()

# %%
sample_new = np.random.choice(income["x"], size=128, replace=False)

# %%
def konfidenzintervall_mu(sample, anz):
    resample_mu_hat = []
    for _ in range(anz):
        mu_hat = np.random.choice(sample, size=128, replace=True).mean()
        resample_mu_hat.append(mu_hat)
        resample_mu_hat.sort()
    konf_left_95 = resample_mu_hat[int(anz / 100 * (100 - 95) / 2)]
    konf_right_95 = resample_mu_hat[int(anz / 100 * (100 + 95) / 2)]
    konf_left_99 = resample_mu_hat[int(anz / 100 * (100 - 99) / 2)]
    konf_right_99 = resample_mu_hat[int(anz / 100 * (100 + 99) / 2)]
    return (konf_left_95, konf_left_99, konf_right_95, konf_right_99)


konfidenzintervall_mu(sample_new, 50)
# Out:
# (69330.5078125, 68048.609375, 79918.46875, 81420.53125)

# %%
income_mu = income["x"].mean(axis=0)

import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe = np.random.choice(income["x"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_mu(stichprobe, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(income_mu, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=income_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > income_mu or right_95[i] < income_mu:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(income_mu - 0.75 * income_std, income_mu + 0.75 * income_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(income_mu, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=income_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > income_mu or right_99[i] < income_mu:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(income_mu - 0.75 * income_std, income_mu + 0.75 * income_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %% [markdown]
# ### <span style="color:rgb(160,0,86)">Aufgabe 3</span>
#
# Laden Sie die Datei *Palette.sav* im Ordner Daten. In dieser Datei sind **Gewicht**, **Höhe** und **Breite** von 750 Hühnereiern, die von Hühnern der Rasse Loheimer Braun gelegt wurden. Nehmen Sie je 100  **Zufallsstichproben** vom Umfang $n=4,8,16,32,64,128$ aus diesen Daten.
#
# - Schätzen Sie die wahren Mittelwerte und die wahren Standardabweichungen des Gewichts, der Höhe und der Bereite mit diesen Stichproben und vergleichen Sie diese Schätzungen mit den wahren Parametern.
# - Bestimmen Sie mit Resamples basierend auf einer Stichprobe mit $n=128$ ein 95\%- und ein 99\%-Konfidenzintervall für die Mittelwerte und die Standardabweichungen.

# %% [markdown]
# ***
#
# ### <span style="color:rgb(160,0,86)">Lösungsvorschlag</span>

# %%
import numpy as np
import pandas as pd

# pip install pyreadstat
eggs = pd.read_spss("Daten/Palette.sav")
eggs.head()
# Out:
#     Nummer  Breite  Höhe  Gewicht
# 0  10001.0    44.7  58.5     66.5
# 1  10002.0    44.0  60.1     65.5
# 2  10003.0    44.4  57.2     63.0
# 3  10004.0    43.3  59.2     64.5
# 4  10005.0    45.3  57.6     65.5

# %%
def samples(x, anz, n):
    Samples = ["x" + str(i) for i in range(n)]
    sample = pd.DataFrame(columns=Samples)
    for i in range(anz):
        sample.loc[i] = np.random.choice(x, size=n, replace=True)
    sample["mu_hat"] = sample[Samples].mean(axis=1)
    sample["std_hat"] = sample[Samples].std(axis=1, ddof=1)
    return sample

# %%
sample_4 = samples(eggs["Breite"], 1000, 4)
sample_8 = samples(eggs["Breite"], 1000, 8)
sample_16 = samples(eggs["Breite"], 1000, 16)
sample_32 = samples(eggs["Breite"], 1000, 32)
sample_64 = samples(eggs["Breite"], 1000, 64)
sample_128 = samples(eggs["Breite"], 1000, 128)

breite_mu = eggs["Breite"].mean(axis=0)
breite_std = eggs["Breite"].std(axis=0, ddof=0)

#je ein Dichtediagramm für 
# - die Stichprobenmittelwerte
# - die Stichprobenstandardabweichungen
import matplotlib.pyplot as plt
import seaborn as sns


def draw_mu(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(breite_mu - 2 * breite_std, breite_mu + 2 * breite_std)
    ax = plt.axvline(breite_mu, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\mu=$" + "{m:1.1f}".format(m=breite_mu),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenmittelwerte für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


def draw_std(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(breite_std - 1.5 * breite_std, breite_std + 1.5 * breite_std)
    ax = plt.axvline(breite_std, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\sigma=$" + "{m:1.1f}".format(m=breite_std),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenstandardabweichungen für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


fig = plt.figure(figsize=(15, 30))
ax = fig.add_subplot(6, 2, 1)
draw_mu(sample_4["mu_hat"], "4")
ax = fig.add_subplot(6, 2, 2)
draw_std(sample_4["std_hat"], "4")
ax = fig.add_subplot(6, 2, 3)
draw_mu(sample_8["mu_hat"], "8")
ax = fig.add_subplot(6, 2, 4)
draw_std(sample_8["std_hat"], "8")
ax = fig.add_subplot(6, 2, 5)
draw_mu(sample_16["mu_hat"], "16")
ax = fig.add_subplot(6, 2, 6)
draw_std(sample_16["std_hat"], "16")
ax = fig.add_subplot(6, 2, 7)
draw_mu(sample_32["mu_hat"], "32")
ax = fig.add_subplot(6, 2, 8)
draw_std(sample_32["std_hat"], "32")
ax = fig.add_subplot(6, 2, 9)
draw_mu(sample_64["mu_hat"], "64")
ax = fig.add_subplot(6, 2, 10)
draw_std(sample_64["std_hat"], "64")
ax = fig.add_subplot(6, 2, 11)
draw_mu(sample_128["mu_hat"], "128")
ax = fig.add_subplot(6, 2, 12)
draw_std(sample_128["std_hat"], "128")

plt.show()

# %%
sample_4 = samples(eggs["Höhe"], 1000, 4)
sample_8 = samples(eggs["Höhe"], 1000, 8)
sample_16 = samples(eggs["Höhe"], 1000, 16)
sample_32 = samples(eggs["Höhe"], 1000, 32)
sample_64 = samples(eggs["Höhe"], 1000, 64)
sample_128 = samples(eggs["Höhe"], 1000, 128)

höhe_mu = eggs["Höhe"].mean(axis=0)
höhe_std = eggs["Höhe"].std(axis=0, ddof=0)

#je ein Dichtediagramm für 
# - die Stichprobenmittelwerte
# - die Stichprobenstandardabweichungen
import matplotlib.pyplot as plt
import seaborn as sns


def draw_mu(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(höhe_mu - 2 * höhe_std, höhe_mu + 2 * höhe_std)
    ax = plt.axvline(höhe_mu, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\mu=$" + "{m:1.1f}".format(m=höhe_mu),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenmittelwerte für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


def draw_std(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(höhe_std - 1.5 * höhe_std, höhe_std + 1.5 * höhe_std)
    ax = plt.axvline(höhe_std, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\sigma=$" + "{m:1.1f}".format(m=höhe_std),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenstandardabweichungen für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


fig = plt.figure(figsize=(15, 30))
ax = fig.add_subplot(6, 2, 1)
draw_mu(sample_4["mu_hat"], "4")
ax = fig.add_subplot(6, 2, 2)
draw_std(sample_4["std_hat"], "4")
ax = fig.add_subplot(6, 2, 3)
draw_mu(sample_8["mu_hat"], "8")
ax = fig.add_subplot(6, 2, 4)
draw_std(sample_8["std_hat"], "8")
ax = fig.add_subplot(6, 2, 5)
draw_mu(sample_16["mu_hat"], "16")
ax = fig.add_subplot(6, 2, 6)
draw_std(sample_16["std_hat"], "16")
ax = fig.add_subplot(6, 2, 7)
draw_mu(sample_32["mu_hat"], "32")
ax = fig.add_subplot(6, 2, 8)
draw_std(sample_32["std_hat"], "32")
ax = fig.add_subplot(6, 2, 9)
draw_mu(sample_64["mu_hat"], "64")
ax = fig.add_subplot(6, 2, 10)
draw_std(sample_64["std_hat"], "64")
ax = fig.add_subplot(6, 2, 11)
draw_mu(sample_128["mu_hat"], "128")
ax = fig.add_subplot(6, 2, 12)
draw_std(sample_128["std_hat"], "128")

plt.show()

# %%
sample_4 = samples(eggs["Gewicht"], 1000, 4)
sample_8 = samples(eggs["Gewicht"], 1000, 8)
sample_16 = samples(eggs["Gewicht"], 1000, 16)
sample_32 = samples(eggs["Gewicht"], 1000, 32)
sample_64 = samples(eggs["Gewicht"], 1000, 64)
sample_128 = samples(eggs["Gewicht"], 1000, 128)

gewicht_mu = eggs["Gewicht"].mean(axis=0)
gewicht_std = eggs["Gewicht"].std(axis=0, ddof=0)

#je ein Dichtediagramm für 
# - die Stichprobenmittelwerte
# - die Stichprobenstandardabweichungen
import matplotlib.pyplot as plt
import seaborn as sns


def draw_mu(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(gewicht_mu - 2 * gewicht_std, gewicht_mu + 2 * gewicht_std)
    ax = plt.axvline(gewicht_mu, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\mu=$" + "{m:1.1f}".format(m=gewicht_mu),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenmittelwerte für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


def draw_std(x, anz):
    ax = sns.histplot(x, stat="density", color="red")
    ax = plt.xlim(gewicht_std - 1.5 * gewicht_std, gewicht_std + 1.5 * gewicht_std)
    ax = plt.axvline(gewicht_std, color="blue", lw=2, linestyle="dashed")
    ax = plt.text(0.65, 0.9, r"$\sigma=$" + "{m:1.1f}".format(m=gewicht_std),
                  fontsize=12, transform=plt.gca().transAxes)
    ax = plt.title("1000 Stichprobenstandardabweichungen für n = " + anz,
                   fontsize=13, pad=10)
    ax = plt.xlabel("")
    ax = plt.xticks([])
    ax = plt.yticks([])


fig = plt.figure(figsize=(15, 30))
ax = fig.add_subplot(6, 2, 1)
draw_mu(sample_4["mu_hat"], "4")
ax = fig.add_subplot(6, 2, 2)
draw_std(sample_4["std_hat"], "4")
ax = fig.add_subplot(6, 2, 3)
draw_mu(sample_8["mu_hat"], "8")
ax = fig.add_subplot(6, 2, 4)
draw_std(sample_8["std_hat"], "8")
ax = fig.add_subplot(6, 2, 5)
draw_mu(sample_16["mu_hat"], "16")
ax = fig.add_subplot(6, 2, 6)
draw_std(sample_16["std_hat"], "16")
ax = fig.add_subplot(6, 2, 7)
draw_mu(sample_32["mu_hat"], "32")
ax = fig.add_subplot(6, 2, 8)
draw_std(sample_32["std_hat"], "32")
ax = fig.add_subplot(6, 2, 9)
draw_mu(sample_64["mu_hat"], "64")
ax = fig.add_subplot(6, 2, 10)
draw_std(sample_64["std_hat"], "64")
ax = fig.add_subplot(6, 2, 11)
draw_mu(sample_128["mu_hat"], "128")
ax = fig.add_subplot(6, 2, 12)
draw_std(sample_128["std_hat"], "128")

plt.show()

# %%
sample_breite = np.random.choice(eggs["Breite"], size=128, replace=False)
sample_höhe = np.random.choice(eggs["Höhe"], size=128, replace=False)
sample_gewicht = np.random.choice(eggs["Gewicht"], size=128, replace=False)

# %%
def konfidenzintervall_std(sample, anz):
    resample_std_hat = []
    for _ in range(anz):
        std_hat = np.random.choice(sample, size=128, replace=True).std(ddof=1)
        resample_std_hat.append(std_hat)
        resample_std_hat.sort()
    konf_left_95 = resample_std_hat[int(anz / 100 * (100 - 95) / 2)]
    konf_right_95 = resample_std_hat[int(anz / 100 * (100 + 95) / 2)]
    konf_left_99 = resample_std_hat[int(anz / 100 * (100 - 99) / 2)]
    konf_right_99 = resample_std_hat[int(anz / 100 * (100 + 99) / 2)]
    return (konf_left_95, konf_left_99, konf_right_95, konf_right_99)


l_95, l_99, r_95, r_99 = np.round(konfidenzintervall_mu(sample_breite, 500), 2)
print("95%-Konfidenzintervall für mittlere Breite = [" + str(l_95) + "," + str(r_95) + "]")
print("99%-Konfidenzintervall für mittlere Breite = [" + str(l_99) + "," + str(r_99) + "]")
print("Wahre mittlere Breite = " + str(np.round(breite_mu, 2)))

l_95, l_99, r_95, r_99 = np.round(konfidenzintervall_std(sample_breite, 500), 2)
print("95%-Konfidenzintervall für std der Breite = [" + str(l_95) + "," + str(r_95) + "]")
print("99%-Konfidenzintervall für std der Breite = [" + str(l_99) + "," + str(r_99) + "]")
print("Wahre std der Breite = " + str(np.round(breite_std, 2)))

l_95, l_99, r_95, r_99 = np.round(konfidenzintervall_mu(sample_höhe, 500), 2)
print("95%-Konfidenzintervall für mittlere Höhe = [" + str(l_95) + "," + str(r_95) + "]")
print("99%-Konfidenzintervall für mittlere Höhe = [" + str(l_99) + "," + str(r_99) + "]")
print("Wahre mittlere Höhe = " + str(np.round(höhe_mu, 2)))

l_95, l_99, r_95, r_99 = np.round(konfidenzintervall_std(sample_höhe, 500), 2)
print("95%-Konfidenzintervall für std der Höhe = [" + str(l_95) + "," + str(r_95) + "]")
print("99%-Konfidenzintervall für std der Höhe = [" + str(l_99) + "," + str(r_99) + "]")
print("Wahre std der Höhe = " + str(np.round(höhe_std, 2)))

l_95, l_99, r_95, r_99 = np.round(konfidenzintervall_mu(sample_gewicht, 500), 2)
print("95%-Konfidenzintervall für mittleres Gewicht = [" + str(l_95) + "," + str(r_95) + "]")
print("99%-Konfidenzintervall für mittleres Gewicht = [" + str(l_99) + "," + str(r_99) + "]")
print("Wahres mittleres Gewicht = " + str(np.round(gewicht_mu, 2)))

l_95, l_99, r_95, r_99 = np.round(konfidenzintervall_std(sample_gewicht, 500), 2)
print("95%-Konfidenzintervall für std des Gewichts = [" + str(l_95) + "," + str(r_95) + "]")
print("99%-Konfidenzintervall für std des Gewichts = [" + str(l_99) + "," + str(r_99) + "]")
print("Wahre std des Gewichts = " + str(np.round(gewicht_std, 2)))
# Out:
# 95%-Konfidenzintervall für mittlere Breite = [44.25,44.67]
# 99%-Konfidenzintervall für mittlere Breite = [44.19,44.73]
# Wahre mittlere Breite = 44.22
# 95%-Konfidenzintervall für std der Breite = [1.13,1.39]
# 99%-Konfidenzintervall für std der Breite = [1.09,1.41]
# Wahre std der Breite = 1.18
# 95%-Konfidenzintervall für mittlere Höhe = [56.45,57.07]
# 99%-Konfidenzintervall für mittlere Höhe = [56.38,57.16]
# Wahre mittlere Höhe = 57.09
# 95%-Konfidenzintervall für std der Höhe = [1.69,2.09]
# 99%-Konfidenzintervall für std der Höhe = [1.64,2.16]
# Wahre std der Höhe = 2.09
# 95%-Konfidenzintervall für mittleres Gewicht = [62.33,63.96]
# 99%-Konfidenzintervall für mittleres Gewicht = [62.1,64.14]
# Wahres mittleres Gewicht = 62.78
# 95%-Konfidenzintervall für std des Gewichts = [4.16,5.13]
# 99%-Konfidenzintervall für std des Gewichts = [4.01,5.34]
# Wahre std des Gewichts = 4.72

# %%
import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe_b = np.random.choice(eggs["Breite"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_mu(stichprobe_b, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(breite_mu, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=breite_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > breite_mu or right_95[i] < breite_mu:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(breite_mu - 0.75 * breite_std, breite_mu + 0.75 * breite_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(breite_mu, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=breite_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > breite_mu or right_99[i] < breite_mu:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(breite_mu - 0.75 * breite_std, breite_mu + 0.75 * breite_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %%
import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe_b = np.random.choice(eggs["Breite"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_std(stichprobe_b, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(breite_std, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\sigma=$" + "{m:1.1f}".format(m=breite_std),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > breite_std or right_95[i] < breite_std:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(breite_std - 0.5 * breite_std, breite_std + 0.5 * breite_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(breite_std, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\sigma=$" + "{m:1.1f}".format(m=breite_std),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > breite_std or right_99[i] < breite_std:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(breite_std - 0.5 * breite_std, breite_std + 0.5 * breite_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %%
import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe_h = np.random.choice(eggs["Höhe"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_mu(stichprobe_h, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(höhe_mu, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=höhe_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > höhe_mu or right_95[i] < höhe_mu:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(höhe_mu - 0.75 * höhe_std, höhe_mu + 0.75 * höhe_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(höhe_mu, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=höhe_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > höhe_mu or right_99[i] < höhe_mu:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(höhe_mu - 0.75 * höhe_std, höhe_mu + 0.75 * höhe_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %%
import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe_b = np.random.choice(eggs["Höhe"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_std(stichprobe_b, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(höhe_std, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\sigma=$" + "{m:1.1f}".format(m=höhe_std),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > höhe_std or right_95[i] < höhe_std:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(höhe_std - 0.5 * höhe_std, höhe_std + 0.5 * höhe_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(höhe_std, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\sigma=$" + "{m:1.1f}".format(m=höhe_std),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > höhe_std or right_99[i] < höhe_std:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(höhe_std - 0.5 * höhe_std, höhe_std + 0.5 * höhe_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %%
import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe_h = np.random.choice(eggs["Gewicht"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_mu(stichprobe_h, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(gewicht_mu, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=gewicht_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > gewicht_mu or right_95[i] < gewicht_mu:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(gewicht_mu - 0.75 * gewicht_std, gewicht_mu + 0.75 * gewicht_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(gewicht_mu, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\mu=$" + "{m:1.1f}".format(m=gewicht_mu),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > gewicht_mu or right_99[i] < gewicht_mu:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(gewicht_mu - 0.75 * gewicht_std, gewicht_mu + 0.75 * gewicht_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %%
import matplotlib.pyplot as plt

left_95 = []
left_99 = []
right_95 = []
right_99 = []
for i in range(200):
    stichprobe_b = np.random.choice(eggs["Gewicht"], size=128, replace=False)
    l_95, l_99, r_95, r_99 = konfidenzintervall_std(stichprobe_b, 500)
    left_95.append(l_95)
    left_99.append(l_99)
    right_95.append(r_95)
    right_99.append(r_99)

fig = plt.figure(figsize=(12, 15))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = plt.axvline(gewicht_std, color="blue", lw=2, linestyle="dashed")
ax1 = plt.text(0.65, 0.975, r"$\sigma=$" + "{m:1.1f}".format(m=gewicht_std),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_95[i] > gewicht_std or right_95[i] < gewicht_std:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="red")
    else:
        ax1 = plt.hlines(i / 10, left_95[i], right_95[i], lw=2, color="green")
ax1 = plt.xlim(gewicht_std - 0.5 * gewicht_std, gewicht_std + 0.5 * gewicht_std)
ax1 = plt.title("200 95%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax1 = plt.xticks(rotation=45)
ax1 = plt.yticks([])

ax2 = fig.add_subplot(1, 2, 2)
ax2 = plt.axvline(gewicht_std, color="blue", lw=2, linestyle="dashed")
ax2 = plt.text(0.65, 0.975, r"$\sigma=$" + "{m:1.1f}".format(m=gewicht_std),
               fontsize=12, transform=plt.gca().transAxes)
for i in range(200):
    if left_99[i] > gewicht_std or right_99[i] < gewicht_std:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="red")
    else:
        ax2 = plt.hlines(i / 10, left_99[i], right_99[i], lw=2, color="green")
ax2 = plt.xlim(gewicht_std - 0.5 * gewicht_std, gewicht_std + 0.5 * gewicht_std)
ax2 = plt.title("200 99%-Konfidenzintervalle",
                fontsize=13, pad=10)
ax2 = plt.xticks(rotation=45)
ax2 = plt.yticks([])

plt.show()

# %% [markdown]
# ![HSLU](../../../../Users/Lino/Downloads/SW06-final/SW06-final/Bilder/LogoHSLU.png)
